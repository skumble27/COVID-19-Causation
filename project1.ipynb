# %%
# Importing Modules
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Reading the CSV File
raw_data_cv19 = pd.read_csv('Resources\owid-covid-data.csv')

# %%
# Reading the Raw Data Frame and sampling 10
raw_data_cv19.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          0.0        0.0
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          0.0        0.0
# 4      ABW  North America    Aruba  2020-03-22          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0               0.000           0.0         0.0                  0.0  ...
# 1               0.286           0.0         0.0                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
# 3               0.286           0.0         0.0                  0.0  ...
# 4               0.286           0.0         0.0                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
# Replacing all the NaN to zero
raw_data_cv19 = raw_data_cv19.fillna(0)
raw_data_cv19.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          0.0        0.0
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          0.0        0.0
# 4      ABW  North America    Aruba  2020-03-22          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0               0.000           0.0         0.0                  0.0  ...
# 1               0.286           0.0         0.0                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
# 3               0.286           0.0         0.0                  0.0  ...
# 4               0.286           0.0         0.0                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
# Quick Perusal of US Data Frame
us_raw_data = raw_data_cv19[raw_data_cv19['location']=='United States']
us_raw_data
# Out:
#       iso_code      continent       location        date  total_cases  \
# 43836      USA  North America  United States  2019-12-31          0.0
# 43837      USA  North America  United States  2020-01-01          0.0
# 43838      USA  North America  United States  2020-01-02          0.0
# 43839      USA  North America  United States  2020-01-03          0.0
# 43840      USA  North America  United States  2020-01-04          0.0
# ...        ...            ...            ...         ...          ...
# 44106      USA  North America  United States  2020-09-26    7033430.0
# 44107      USA  North America  United States  2020-09-27    7078798.0
# 44108      USA  North America  United States  2020-09-28    7115046.0
# 44109      USA  North America  United States  2020-09-29    7148044.0
# 44110      USA  North America  United States  2020-09-30    7191061.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
# Checking Column names
raw_data_cv19.columns
# Out:
# Index([&#39;iso_code&#39;, &#39;continent&#39;, &#39;location&#39;, &#39;date&#39;, &#39;total_cases&#39;, &#39;new_cases&#39;,
#        &#39;new_cases_smoothed&#39;, &#39;total_deaths&#39;, &#39;new_deaths&#39;,
#        &#39;new_deaths_smoothed&#39;, &#39;total_cases_per_million&#39;,
#        &#39;new_cases_per_million&#39;, &#39;new_cases_smoothed_per_million&#39;,
#        &#39;total_deaths_per_million&#39;, &#39;new_deaths_per_million&#39;,
#        &#39;new_deaths_smoothed_per_million&#39;, &#39;new_tests&#39;, &#39;total_tests&#39;,
#        &#39;total_tests_per_thousand&#39;, &#39;new_tests_per_thousand&#39;,
#        &#39;new_tests_smoothed&#39;, &#39;new_tests_smoothed_per_thousand&#39;,
#        &#39;tests_per_case&#39;, &#39;positive_rate&#39;, &#39;tests_units&#39;, &#39;stringency_index&#39;,
#        &#39;population&#39;, &#39;population_density&#39;, &#39;median_age&#39;, &#39;aged_65_older&#39;,
# ...

# %% [markdown]
# # Question 2 Data Frame

# %%
# Columns to drop for pre-existing health factors
q2_data_frame = raw_data_cv19.drop(columns=['iso_code','date','new_cases_smoothed','new_deaths_smoothed','new_cases_smoothed_per_million','new_deaths_smoothed_per_million','new_tests', 'total_tests', 'total_tests_per_thousand', 'new_tests_per_thousand',
       'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
       'tests_per_case','tests_units', 'stringency_index','extreme_poverty','population_density','handwashing_facilities', 'hospital_beds_per_thousand',])

# Taking the last row to indicate the last reported case
q2_data_frame = q2_data_frame.drop_duplicates(subset=['location'],keep='last')

q2_data_frame.to_csv('Cleaned_Data\q2_data.csv')

q2_data_frame
# Out:
#            continent       location  total_cases  new_cases  total_deaths  \
# 196    North America          Aruba       3934.0       62.0          26.0
# 471             Asia    Afghanistan      39254.0       15.0        1458.0
# 664           Africa         Angola       4905.0      108.0         179.0
# 852    North America       Anguilla          3.0        0.0           0.0
# 1058          Europe        Albania      13518.0      127.0         384.0
# ...              ...            ...          ...        ...           ...
# 46175         Africa   South Africa     672572.0      903.0       16667.0
# 46371         Africa         Zambia      14715.0       55.0         332.0
# 46565         Africa       Zimbabwe       7837.0       21.0         228.0
# 46840              0          World   33714595.0   277930.0     1008932.0
# 47115              0  International        696.0        0.0           7.0
#
#        new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %% [markdown]
# # Question 1 Data Frame

# %%
raw_data_cv19.columns
# Out:
# Index([&#39;iso_code&#39;, &#39;continent&#39;, &#39;location&#39;, &#39;date&#39;, &#39;total_cases&#39;, &#39;new_cases&#39;,
#        &#39;new_cases_smoothed&#39;, &#39;total_deaths&#39;, &#39;new_deaths&#39;,
#        &#39;new_deaths_smoothed&#39;, &#39;total_cases_per_million&#39;,
#        &#39;new_cases_per_million&#39;, &#39;new_cases_smoothed_per_million&#39;,
#        &#39;total_deaths_per_million&#39;, &#39;new_deaths_per_million&#39;,
#        &#39;new_deaths_smoothed_per_million&#39;, &#39;new_tests&#39;, &#39;total_tests&#39;,
#        &#39;total_tests_per_thousand&#39;, &#39;new_tests_per_thousand&#39;,
#        &#39;new_tests_smoothed&#39;, &#39;new_tests_smoothed_per_thousand&#39;,
#        &#39;tests_per_case&#39;, &#39;positive_rate&#39;, &#39;tests_units&#39;, &#39;stringency_index&#39;,
#        &#39;population&#39;, &#39;population_density&#39;, &#39;median_age&#39;, &#39;aged_65_older&#39;,
# ...

# %%
q1_data_frame = raw_data_cv19.drop(columns=['iso_code','date','new_cases',
       'new_cases_smoothed', 'new_deaths',
       'new_deaths_smoothed', 'total_cases_per_million',
       'new_cases_per_million', 'new_cases_smoothed_per_million',
       'total_deaths_per_million', 'new_deaths_per_million',
       'new_deaths_smoothed_per_million','new_tests','total_tests_per_thousand', 'new_tests_per_thousand',
       'new_tests_smoothed', 'new_tests_smoothed_per_thousand','positive_rate', 'tests_units','cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers','life_expectancy'])
q1_data_frame = q1_data_frame.drop_duplicates(subset=['location'],keep='last')
q1_data_frame.to_csv('Cleaned_Data\q1_data.csv')
q1_data_frame
# Out:
#            continent       location  total_cases  total_deaths  total_tests  \
# 196    North America          Aruba       3934.0          26.0          0.0
# 471             Asia    Afghanistan      39254.0        1458.0          0.0
# 664           Africa         Angola       4905.0         179.0          0.0
# 852    North America       Anguilla          3.0           0.0          0.0
# 1058          Europe        Albania      13518.0         384.0          0.0
# ...              ...            ...          ...           ...          ...
# 46175         Africa   South Africa     672572.0       16667.0          0.0
# 46371         Africa         Zambia      14715.0         332.0          0.0
# 46565         Africa       Zimbabwe       7837.0         228.0          0.0
# 46840              0          World   33714595.0     1008932.0          0.0
# 47115              0  International        696.0           7.0          0.0
#
# ...

# %%
## Plotting countries on GDP
continent_group = q1_data_frame.sort_values(by='gdp_per_capita',ascending=False)
continent_group
# Out:
#            continent                  location  total_cases  total_deaths  \
# 36174           Asia                     Qatar     125533.0         214.0
# 26752         Europe                Luxembourg       8431.0         124.0
# 37829           Asia                 Singapore      57742.0          27.0
# 6740            Asia                    Brunei        146.0           3.0
# 20633         Europe                   Ireland      35740.0        1803.0
# ...              ...                       ...          ...           ...
# 41126  North America  Turks and Caicos Islands        686.0           6.0
# 10130  North America                      Cuba       5531.0         122.0
# 18509        Oceania                      Guam       2443.0          47.0
# 18113  North America                 Greenland         14.0           0.0
# 47115              0             International        696.0           7.0
#
#        total_tests  tests_per_case  stringency_index  population  \
# ...
